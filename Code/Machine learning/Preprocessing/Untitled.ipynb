# %%
# !pip install tsfresh

# %%
import os
import pandas as pd
import numpy as np
from tsfresh import extract_features
from tsfresh.feature_extraction import MinimalFCParameters, extract_features
from tsfresh.utilities.dataframe_functions import impute

# %%
# Read the DataFrame from the HDF5 file
df = pd.read_csv(r"C:\Users\GHB\Desktop\SCREW PROJECT\Machine Learning\Features\tsfresh_efficient_features.csv")

# %%
print(df)
# Out:
#           Unnamed: 0  Angle (deg)__variance_larger_than_standard_deviation  \
# 0     id030520234000                                                1.0
# 1     id030520234001                                                1.0
# 2     id030520234002                                                1.0
# 3     id030520234003                                                1.0
# 4     id030520234004                                                1.0
# ...              ...                                                ...
# 1336  id280420233082                                                1.0
# 1337  id280420233083                                                1.0
# 1338  id280420233084                                                1.0
# 1339  id280420233085                                                1.0
# 1340  id280420233086                                                1.0
#
#       Angle (deg)__has_duplicate_max  Angle (deg)__has_duplicate_min  \
# ...

# %%
df = df.apply(pd.to_numeric, errors='coerce')


# Use the `impute()` function to replace all NaNs
df_imputed = impute(df)
# Out:
# G:\PROGRAMI\Anaconda3\lib\site-packages\tsfresh\utilities\dataframe_functions.py:198: RuntimeWarning: The columns ['Unnamed: 0'
#  'Angle (deg)__query_similarity_count__query_None__threshold_0.0'
#  'Current (V)__query_similarity_count__query_None__threshold_0.0'
#  'Depth (mm)__friedrich_coefficients__coeff_0__m_3__r_30'
#  'Depth (mm)__friedrich_coefficients__coeff_1__m_3__r_30'
#  'Depth (mm)__friedrich_coefficients__coeff_2__m_3__r_30'
#  'Depth (mm)__friedrich_coefficients__coeff_3__m_3__r_30'
#  'Depth (mm)__max_langevin_fixed_point__m_3__r_30'
#  'Depth (mm)__query_similarity_count__query_None__threshold_0.0'
#  'Nset (1/min)__friedrich_coefficients__coeff_0__m_3__r_30'
#  'Nset (1/min)__friedrich_coefficients__coeff_1__m_3__r_30'
#  'Nset (1/min)__friedrich_coefficients__coeff_2__m_3__r_30'
#  'Nset (1/min)__friedrich_coefficients__coeff_3__m_3__r_30'
#  'Nset (1/min)__max_langevin_fixed_point__m_3__r_30'
#  'Nset (1/min)__query_similarity_count__query_None__threshold_0.0'
# ...
