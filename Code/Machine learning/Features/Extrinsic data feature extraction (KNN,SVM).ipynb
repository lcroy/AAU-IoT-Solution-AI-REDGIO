# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in g:\programi\anaconda3\lib\site-packages (0.9.2)
# Requirement already satisfied: numba>=0.45.1 in g:\programi\anaconda3\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: scipy>=1.2.0 in g:\programi\anaconda3\lib\site-packages (from librosa) (1.10.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\ghb\appdata\roaming\python\python39\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ghb\appdata\roaming\python\python39\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in g:\programi\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in g:\programi\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\ghb\appdata\roaming\python\python39\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in g:\programi\anaconda3\lib\site-packages (from librosa) (23.1)
# Requirement already satisfied: decorator>=4.0.10 in g:\programi\anaconda3\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: resampy>=0.2.2 in g:\programi\anaconda3\lib\site-packages (from librosa) (0.4.2)
# Requirement already satisfied: numpy>=1.17.0 in g:\programi\anaconda3\lib\site-packages (from librosa) (1.20.3)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in g:\programi\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.37.0)
# Requirement already satisfied: setuptools in g:\programi\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: requests>=2.19.0 in g:\programi\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: appdirs>=1.3.0 in g:\programi\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in g:\programi\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in g:\programi\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in g:\programi\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in g:\programi\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in g:\programi\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in g:\programi\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in g:\programi\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)

# %%
import os
import numpy as np
import librosa
import pandas as pd

# %%
# Feature extraction 1 try 33% Accuracy


import os
import librosa
import pandas as pd
import numpy as np

def extract_features(file_path):
   
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast') 
        chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
        spec_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate)
        tonnetz = librosa.feature.tonnetz(y=audio, sr=sample_rate)
        mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sample_rate)
        zero_crossing_rate = librosa.feature.zero_crossing_rate(audio)
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sample_rate)

        # We will use the mean values of the computed features here
        # You can use any statistical measures such as median, mode, etc.
        features = [np.mean(chroma_stft), np.mean(spec_contrast), np.mean(tonnetz), np.mean(spectral_bandwidth), np.mean(zero_crossing_rate), np.mean(spectral_rolloff)] + [np.mean(e) for e in mfcc]

    except Exception as e:
        print("Error encountered while parsing file: ", file_path)
        return None 

    return features


# directory containing your audio files
root_dir = r"C:\Users\GHB\Desktop\SCREW PROJECT\Machine Learning\Final data\Extrinsic data (clean)" # replace with your directory

# Construct the column names
column_names = ['chroma_stft', 'spec_contrast', 'tonnetz', 'spectral_bandwidth', 'zero_crossing_rate', 'spectral_rolloff'] + [f'mfcc_{i}' for i in range(1, 41)]

# add 'filename' to the column names
column_names.append('filename')

# Create a dataframe that will hold the features
features_df = pd.DataFrame(columns = column_names)

# Walk through the directory (and subdirectories)
for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        # Only process .wav files
        if file.endswith(".wav"):
            file_path = subdir + os.sep + file
            data = extract_features(file_path)

            # Extract the base file name without extension
            filename = os.path.splitext(os.path.basename(file_path))[0]

            # Add the features to the dataframe
            data_dict = {column_names[i]: data[i] for i in range(len(data))}
            data_dict['filename'] = filename
            features_df = features_df.append(data_dict, ignore_index=True)
# Out:
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=664
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=568
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=768
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=728
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=736
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=744
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=760
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=720
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=752
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=784
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=792
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=712
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=704
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=776
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=672
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=696
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=688
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=616
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=800
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=560
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=632
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=912
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=808
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=864
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=816
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=848
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=824
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=680
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=600
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=624
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=512
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=544
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=528
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=552
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=576
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=520
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=592
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=1008
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=504
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=536
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=640
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=584
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=944
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=472
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=992
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=496
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=608
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=648
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=960
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=480
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=976
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=488
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=456
#   warnings.warn(
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\spectrum.py:256: UserWarning: n_fft=1024 is too large for input signal of length=840
#   warnings.warn(

# %%
# Feature extraction with a smaller window


import os
import librosa
import pandas as pd
import numpy as np

def extract_features(file_path):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast') 
        n_fft = 512  # Lower value for FFT window

        # Check if audio is shorter than n_fft and pad if necessary
        if len(audio) < n_fft:
            audio = np.pad(audio, (0, n_fft - len(audio)), 'constant')

        chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sample_rate, n_fft=n_fft)
        spec_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate, n_fft=n_fft)
        tonnetz = librosa.feature.tonnetz(y=audio, sr=sample_rate)
        mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40, n_fft=n_fft)
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sample_rate, n_fft=n_fft)
        zero_crossing_rate = librosa.feature.zero_crossing_rate(audio)
        spectral_rolloff = librosa.feature.spectral_rolloff(y=audio, sr=sample_rate, n_fft=n_fft)

        features = [np.mean(chroma_stft), np.mean(spec_contrast), np.mean(tonnetz), np.mean(spectral_bandwidth), np.mean(zero_crossing_rate), np.mean(spectral_rolloff)] + [np.mean(e) for e in mfcc]

    except Exception as e:
        print("Error encountered while parsing file: ", file_path)
        return None 

    return features


# directory containing your audio files
root_dir = r"C:\Users\GHB\Desktop\Screwcell dataset\Extrinsic data" # replace with your directory

# Construct the column names
column_names = ['chroma_stft', 'spec_contrast', 'tonnetz', 'spectral_bandwidth', 'zero_crossing_rate', 'spectral_rolloff'] + [f'mfcc_{i}' for i in range(1, 41)]

# add 'filename' to the column names
column_names.append('filename')

# Create a dataframe that will hold the features
features_df = pd.DataFrame(columns = column_names)

# Walk through the directory (and subdirectories)
for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        # Only process .wav files
        if file.endswith(".wav"):
            file_path = subdir + os.sep + file
            data = extract_features(file_path)

            # Extract the base file name without extension
            filename = os.path.splitext(os.path.basename(file_path))[0]

            # Add the features to the dataframe
            data_dict = {column_names[i]: data[i] for i in range(len(data))}
            data_dict['filename'] = filename
            features_df = features_df.append(data_dict, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13824/3879926117.py in <module>
#      51         if file.endswith(".wav"):
#      52             file_path = subdir + os.sep + file
# ---> 53             data = extract_features(file_path)
#      54
#      55             # Extract the base file name without extension
#
# ~\AppData\Local\Temp/ipykernel_13824/3879926117.py in extract_features(file_path)
#       9 def extract_features(file_path):
#      10     try:
# ---> 11         audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast')
#      12         n_fft = 512  # Lower value for FFT window
#      13
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      75             submod_path = f"{package_name}.{attr_to_modules[name]}"
#      76             submod = importlib.import_module(submod_path)
# ---> 77             attr = getattr(submod, name)
#      78
#      79             # If the attribute lives in a file (module) with the same
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      74         elif name in attr_to_modules:
#      75             submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 76             submod = importlib.import_module(submod_path)
#      77             attr = getattr(submod, name)
#      78
#
# G:\PROGRAMI\Anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\audio.py in <module>
#      17 from numba import jit, stencil, guvectorize
#      18 from .fft import get_fftlib
# ---> 19 from .convert import frames_to_samples, time_to_samples
#      20 from .._cache import cache
#      21 from .. import util
#
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\convert.py in <module>
#       5 import re
#       6 import numpy as np
# ----> 7 from . import notation
#       8 from ..util.exceptions import ParameterError
#       9 from ..util.decorators import vectorize
#
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\notation.py in <module>
#       6 import numpy as np
#       7 from numba import jit
# ----> 8 from .intervals import INTERVALS
#       9 from .._cache import cache
#      10 from ..util.exceptions import ParameterError
#
# G:\PROGRAMI\Anaconda3\lib\site-packages\librosa\core\intervals.py in <module>
#       5 from typing import Collection, Dict, List, Union, overload, Iterable
#       6 from typing_extensions import Literal
# ----> 7 import msgpack
#       8 from pkg_resources import resource_filename
#       9 import numpy as np
#
# G:\PROGRAMI\Anaconda3\lib\site-packages\msgpack\__init__.py in <module>
#      12 else:
#      13     try:
# ---> 14         from ._cmsgpack import Packer, unpackb, Unpacker
#      15     except ImportError:
#      16         from .fallback import Packer, unpackb, Unpacker
#
# G:\PROGRAMI\Anaconda3\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
# Fixing names
import pandas as pd

features = features_df[features_df['filename'].str.startswith('e')]
features['filename'] = 'id_' + features['filename']

# Replace "idt" with "id" in the column
features['filename'] = features['filename'].str.replace('id_e', 'id', regex=True)
features = features.rename(columns={'filename': 'id'})
print(features)
# Out:
#       chroma_stft  spec_contrast   tonnetz  spectral_bandwidth  \
# 0        0.596061      19.243907 -0.005266         2270.956832
# 1        0.588911      19.226535 -0.001497         2244.542692
# 2        0.585607      19.282355  0.002229         2241.299579
# 3        0.580079      19.551298 -0.003312         2271.355258
# 4        0.556908      19.318105 -0.003524         2256.037220
# ...           ...            ...       ...                 ...
# 1336     0.576255      19.313264  0.003173         2235.033398
# 1337     0.601177      19.525289  0.002367         2257.486869
# 1338     0.598703      19.372625  0.008883         2268.815816
# 1339     0.472966      19.340586  0.014210         2266.436939
# 1340     0.582771      19.322454 -0.004962         2280.097732
#
#       zero_crossing_rate  spectral_rolloff      mfcc_1     mfcc_2     mfcc_3  \
# 0               0.180804       5585.430908 -364.574493  73.085327 -49.253464
# 1               0.166341       5516.836548 -369.841217  77.422264 -48.497776
# 2               0.184867       5437.466777 -366.542297  71.783287 -43.663475
# 3               0.194819       5631.868843 -369.074219  70.214592 -50.393963
# 4               0.183673       5611.271867 -370.491943  72.533089 -50.100952
# ...                  ...               ...         ...        ...        ...
# 1336            0.182593       5368.809518 -359.364960  81.242683 -46.721958
# 1337            0.183206       5480.668308 -358.665344  77.369339 -47.468803
# 1338            0.169683       5352.756401 -355.141571  89.695564 -39.359619
# 1339            0.190576       5549.787722 -359.630341  77.037712 -44.150211
# 1340            0.186141       5587.633420 -359.886200  78.800575 -46.327755
#
#          mfcc_4  ...    mfcc_32   mfcc_33   mfcc_34   mfcc_35   mfcc_36  \
# 0     29.274887  ...   8.313635 -5.321656  5.688863  2.636749 -0.007261
# 1     28.361113  ...   8.374786 -2.802588  5.074844  3.036380 -0.433906
# 2     27.353281  ...   6.881778 -1.423176  1.337971  4.715841 -2.909443
# 3     29.860140  ...   9.406317 -3.094324  4.391953  2.057418  0.195816
# 4     27.852476  ...   9.268720 -3.960890  5.574724  2.615816 -0.407287
# ...         ...  ...        ...       ...       ...       ...       ...
# 1336  30.847311  ...   4.642770 -7.669148  3.572411  0.568756 -0.362085
# 1337  32.902805  ...   5.030702 -9.998105  5.642989 -0.696157  1.496582
# 1338  31.203709  ...   8.637523 -5.570647  3.087660  1.762853  0.787188
# 1339  30.870872  ...  14.519311 -1.524966  6.475428  0.047266  4.982268
# 1340  31.450697  ...  10.233903 -7.609722  5.179046  2.992604  0.429949
#
#        mfcc_37   mfcc_38   mfcc_39   mfcc_40              id
# 0     1.346813  6.586853  0.256162  5.180595  id030520235006
# 1     0.127297  4.820103  0.100323  4.519959  id030520235007
# 2     6.125939 -0.195765  3.406587  0.996858  id030520236000
# 3     3.667513  2.188496  1.651257  3.264199  id030520236002
# 4     2.121861  4.127666  0.214503  4.517547  id030520236003
# ...        ...       ...       ...       ...             ...
# 1336  2.007410  2.373516 -0.743059  5.275344  id280420232069
# 1337 -5.143201  4.727397 -3.143819  3.928177  id280420232080
# 1338 -0.998388  6.117153 -0.123188  4.839760  id280420233013
# 1339 -0.788518  3.005563  0.855711  4.063168  id280420233045
# 1340  2.500935  4.663921 -2.093643  5.756881  id280420233069
#
# [1341 rows x 47 columns]

# %%
# write features to .csv file
features.to_csv(r"C:\Users\GHB\Desktop\SCREW PROJECT\Machine Learning\Features\audio_features_clean.csv", index=False)
